# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("climate_survey-2023.xlsx")

# %%
X_cols = ['concern', 'aware_cause', 'aware_solve', 
          'satis_mean2', 'aware_tot', 
          'risk', 'risk_me', 'impact_n', 'import_me',
          'eco_at', 'prior_eco', 
          'behave_me', 'behave_other']
D_cols = ['damage_me', 'damage_family', 'damage_commun', 
          'damage_country', 'damage_country_high', 'damage_country_low', #damage_country
          'damage_future', 'damage_org']
psychological_cols = ['distance_index', 'distance_weighted']
motive_cols = ['motive_moral', 'motive_me', 'motive_com']

Y_cols = ['prac_tot']
C_cols = ['sex', 'area', 'edu', 'job', 'child', 'income', 'pol', 
          'media_trust', 'life_satis']

# %% [markdown]
# ### 독립변인과 종속변인 관계

# %% [markdown]
# #### 유의

# %%
sns.jointplot(x='concern', y='prac_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='aware_tot', y='prac_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='impact_n', y='prac_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='damage_country', y='prac_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='damage_future', y='prac_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='damage_org', y='prac_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='eco_at', y='prac_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='prior_eco', y='prac_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='behave_me', y='prac_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='behave_other', y='prac_tot', data=df, kind='reg')
plt.show()

# %% [markdown]
# #### 애매

# %%
sns.jointplot(x='aware_cause', y='prac_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='satis_mean2', y='prac_tot', data=df, kind='reg')
plt.show()

# %% [markdown]
# ##### 통제 후 유의 X

# %% [markdown]
# #### 별 안뜸

# %%
sns.jointplot(x='risk', y='prac_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='risk_me', y='prac_tot', data=df, kind='reg')
plt.show()

# %% [markdown]
# ### 독립 변인 간 관계

# %% [markdown]
# #### 상관 0.3 이상

# %%
sns.jointplot(x='concern', y='aware_tot', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='concern', y='eco_at', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='concern', y='prior_eco', data=df, kind='reg')
plt.show()

# %%
sns.jointplot(x='risk', y='risk_me', data=df, kind='reg')
plt.show()
